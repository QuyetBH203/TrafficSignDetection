# %% [markdown]
# #NHẬN DIỆN BIỂN BÁO GIAO THÔNG CHO NGƯỜI ĐIỀU KHIỂN XE MÁY KHU VỰC THÀNH PHỐ HÀ NỘI
#
#
# ## Nhóm 12
#
# ## Các thành viên thực hiện:
#
#
#
#
#
# *   Nguyễn Viết Văn
#
# *   Lương Ngọc Yên
#
# *   Ngô Trung Tuyên
#
# *   Bùi Hữu Quyết
#
# *   Trần Duy Anh
#
# *   Nguyễn Quang Anh

# %% [markdown]
# ## Git clone source code và install environment

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/yolov5

# !pip install -r requirements.txt
# Out:
# /kaggle/working/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.1/877.1 kB 14.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %ls /kaggle/working/yolov5

# %%
# Copy the images directory to the target location
# !cp -r /kaggle/input/test-data/images/images /kaggle/working/yolov5/data/

# Optionally, remove the original directory if needed
# (Though for Kaggle's input directory, this isn't necessary, as it's read-only)

# %%
# Copy the images directory to the target location
# !cp -r /kaggle/input/test-data/labels/labels /kaggle/working/yolov5/data

# Optionally, remove the original directory if needed
# (Though for Kaggle's input directory, this isn't necessary, as it's read-only)

# %%
# !cp -r /kaggle/input/custom/custom_data.yaml /kaggle/working/yolov5/data

# %%
# Tải tệp trọng số YOLOv5s từ GitHub
# !wget https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt -P /kaggle/working/yolov5

# %%
# Train YOLOv5
# !python /kaggle/working/yolov5/train.py --img 640 --batch 16 --epochs 40 --data custom_data.yaml --weights /kaggle/working/yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
# !ls /kaggle/working/yolov5/runs/train/exp4/weights/
# Out:
# best.pt  last.pt

# %%
# !python /kaggle/working/yolov5/detect.py --weights /kaggle/working/yolov5/runs/train/exp4/weights/best.pt --data custom_data.yaml --source /kaggle/input/bien40/bien40.jpg --conf 0.5 --save-txt --save-conf
# Out:
# detect: weights=['/kaggle/working/yolov5/runs/train/exp4/weights/best.pt'], source=/kaggle/input/bien40/bien40.jpg, data=custom_data.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7166551 parameters, 0 gradients, 16.2 GFLOPs
# image 1/1 /kaggle/input/bien40/bien40.jpg: 384x640 1 P.127, 31.2ms
# Speed: 0.5ms pre-process, 31.2ms inference, 152.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9
# 1 labels saved to runs/detect/exp9/labels

# %%
#result train in epoch
import pandas as pd
def display_csv(filepath):
    # Đọc tệp CSV
    df = pd.read_csv(filepath)
    
    # Hiển thị dữ liệu
    display(df)
    
# Hiển thị kết quả train với mỗi epoch
display_csv('/kaggle/working/yolov5/runs/train/exp4/results.csv')
# Out:
#                    epoch        train/box_loss        train/obj_loss  \
# 0                      0              0.083039              0.025774
# 1                      1              0.054420              0.019012
# 2                      2              0.050722              0.014485
# 3                      3              0.045393              0.012109
# 4                      4              0.040185              0.010448
# 5                      5              0.036740              0.010368
# 6                      6              0.034728              0.009489
# 7                      7              0.032945              0.009007
# 8                      8              0.032146              0.009022
# 9                      9              0.030162              0.008600
# 10                    10              0.030052              0.008358
# 11                    11              0.029678              0.008196
# 12                    12              0.028555              0.008129
# ...

# %%
# define helper functions

def imShow(path):

  import cv2

  import matplotlib.pyplot as plt

  # %matplotlib inline



  image = cv2.imread(path)

  height, width = image.shape[:2]

  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)



  fig = plt.gcf()

  fig.set_size_inches(18, 10)

  plt.axis("off")

  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))

  plt.show()

# %%
imShow('/kaggle/working/yolov5/runs/detect/exp9/bien40.jpg')

# %%
#Hien thi labels sau khi nhận diện
def display_labels(filepath):
    # Mở và đọc file nhãn
    with open(filepath, 'r') as file:
        labels = file.readlines()
    
    # Hiển thị từng dòng trong file
    print("Nhãn nhận diện trong file:", filepath)
    for label in labels:
       
        print(label.strip())

# Đường dẫn tới file nhãn
filepath = '/kaggle/working/yolov5/runs/detect/exp9/labels/bien40.txt'

# Gọi hàm để hiển thị nhãn
display_labels(filepath)
# Out:
# Nhãn nhận diện trong file: /kaggle/working/yolov5/runs/detect/exp9/labels/bien40.txt
# 18 0.789333 0.28436 0.266667 0.483412 0.717328
